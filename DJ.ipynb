# %%
G={
    's':{'t':10,'y':5},
    't':{'x':1,'y':3},
    'x':{'z':4},
    'y':{'t':3,'z':2,'x':9},
    'z':{'x':6,'s':7}
}
for i in G:
    print(f'{i}-> {G[i]}')
# Out:
# s-> {'t': 10, 'y': 5}
# t-> {'x': 1, 'y': 3}
# x-> {'z': 4}
# y-> {'t': 3, 'z': 2, 'x': 9}
# z-> {'x': 6, 's': 7}

# %%
import math

def INITIALIZE_SINGLE_SOURCE(G, s):
    cost=dict()
    prev=dict()
    print(cost)
    for vertex in G.keys():
        cost[vertex]=math.inf#infinity(rotate(90 degree))
        prev[vertex]=" "
    cost[s]=0
    return cost,prev
